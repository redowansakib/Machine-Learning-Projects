# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.base import BaseEstimator, clone

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, TargetEncoder, PolynomialFeatures
from sklearn.feature_selection import chi2, VarianceThreshold, SelectKBest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest
from sklearn.compose import ColumnTransformer
from sklearn.utils.class_weight import compute_sample_weight

from xgboost import XGBClassifier

from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTENC
from imblearn.under_sampling import EditedNearestNeighbours, CondensedNearestNeighbour, NearMiss
from imblearn.pipeline import Pipeline
import umap.umap_ as umap

# !pip install optuna

import optuna
from optuna.visualization import plot_optimization_history, plot_parallel_coordinate, plot_param_importances

import time

seed=42
# Out:
# Requirement already satisfied: optuna in c:\users\acer\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\acer\anaconda3\lib\site-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in c:\users\acer\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\acer\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\acer\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\acer\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\acer\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\acer\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\acer\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
df = pd.read_csv('covtype_decoded.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Elevation                           581012 non-null  int64
#  1   Aspect                              581012 non-null  int64
#  2   Slope                               581012 non-null  int64
#  3   Horizontal_Distance_To_Hydrology    581012 non-null  int64
#  4   Vertical_Distance_To_Hydrology      581012 non-null  int64
#  5   Horizontal_Distance_To_Roadways     581012 non-null  int64
#  6   Hillshade_9am                       581012 non-null  int64
#  7   Hillshade_Noon                      581012 non-null  int64
#  8   Hillshade_3pm                       581012 non-null  int64
#  9   Horizontal_Distance_To_Fire_Points  581012 non-null  int64
#  10  Wilderness                          581012 non-null  object
#  11  Soil_Type                           581012 non-null  int64
#  12  Cover_Type                          581012 non-null  object
# dtypes: int64(11), object(2)
# memory usage: 57.6+ MB

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y.value_counts()
# Out:
# Cover_Type
# Lodgepole Pine       283301
# Spruce/Fir           211840
# Ponderosa Pine        35754
# Krummholz             20510
# Douglas-fir           17367
# Aspen                  9493
# Cottonwood/Willow      2747
# Name: count, dtype: int64

# %%
num = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
cat = [ 'Wilderness', 'Soil_Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.02,random_state=seed,stratify=y)

# %%
print('X_train shape ', X_train.shape)
print('X_test shape ', X_test.shape)
# Out:
# X_train shape  (569391, 12)
# X_test shape  (11621, 12)

# %%
le = LabelEncoder()
y_train_nc = le.fit_transform(y_train)
y_test_nc = le.fit_transform(y_test)

# %%
te = ColumnTransformer([
    ('te', TargetEncoder().set_output(transform='pandas'), cat)
],verbose_feature_names_out=False,remainder='passthrough').set_output(transform='pandas')

preprocessing = Pipeline([
    ('te', te),
    ('ss', StandardScaler().set_output(transform='pandas')),
    ('poly',PolynomialFeatures(degree=2,include_bias=False).set_output(transform='pandas'))
])

X_train_poly = preprocessing.fit_transform(X_train,y_train)

# %%
def model_trainer(model,model_params,X,y,sample_weights=None,n_trials=30):
    def objective(trial):
        params = model_params(trial)
        model.set_params(**params)
        stratified_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        score = cross_val_score(model, X, y, params={'sample_weight':sample_weights}, cv=stratified_cv, scoring='f1_weighted').mean()
        return score

    study = optuna.create_study(direction='maximize',sampler=optuna.samplers.TPESampler(seed=seed))
    study.optimize(objective,n_trials=n_trials)

    model.set_params(**study.best_trial.params)
    model.fit(X,y,sample_weight=sample_weights)

    return study, model

# %%
def xgb_params(trial):
    return {
                'max_depth': trial.suggest_int('max_depth', 3, 12),
                'max_leaves': trial.suggest_int('max_leaves', 8, 256),
                'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
                'gamma': trial.suggest_float('gamma', 0.0, 1.0),
                'subsample': trial.suggest_float('subsample', 0.6, 1.0),
                'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
                'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.6, 1.0),
                'colsample_bynode': trial.suggest_float('colsample_bynode', 0.6, 1.0),
                'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
                'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
                'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
                'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
                'max_delta_step': trial.suggest_int('max_delta_step', 0, 10),
                'max_bin':trial.suggest_int('xgb__max_bin', 64, 1024, step=64),
            }

xgb = XGBClassifier(tree_method='hist',
                    eval_metric='mlogloss',
                    # device='cuda',
                    random_state=seed)

sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_nc)

xgb_study, xgb_model = model_trainer(xgb,xgb_params,X_train_poly,y_train_nc,sample_weights)
# Out:
# [I 2025-05-11 13:44:23,177] A new study created in memory with name: no-name-2589674c-19a9-4f12-ae57-13915dd1ab63
# [I 2025-05-11 15:01:53,173] Trial 0 finished with value: 0.9139781306277092 and parameters: {'max_depth': 6, 'max_leaves': 244, 'min_child_weight': 8, 'gamma': 0.5986584841970366, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'colsample_bylevel': 0.6232334448672797, 'colsample_bynode': 0.9464704583099741, 'learning_rate': 0.07725378389307355, 'n_estimators': 723, 'reg_alpha': 0.020584494295802447, 'reg_lambda': 0.9699098521619943, 'max_delta_step': 9, 'xgb__max_bin': 256}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-11 16:41:36,208] Trial 1 finished with value: 0.7241682352498786 and parameters: {'max_depth': 4, 'max_leaves': 53, 'min_child_weight': 4, 'gamma': 0.5247564316322378, 'subsample': 0.7727780074568463, 'colsample_bytree': 0.7164916560792167, 'colsample_bylevel': 0.8447411578889518, 'colsample_bynode': 0.6557975442608167, 'learning_rate': 0.027010527749605478, 'n_estimators': 398, 'reg_alpha': 0.45606998421703593, 'reg_lambda': 0.7851759613930136, 'max_delta_step': 2, 'xgb__max_bin': 576}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-11 17:15:23,125] Trial 2 finished with value: 0.6800279833806143 and parameters: {'max_depth': 8, 'max_leaves': 19, 'min_child_weight': 7, 'gamma': 0.17052412368729153, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'colsample_bylevel': 0.9862528132298237, 'colsample_bynode': 0.9233589392465844, 'learning_rate': 0.028180680291847244, 'n_estimators': 142, 'reg_alpha': 0.6842330265121569, 'reg_lambda': 0.4401524937396013, 'max_delta_step': 1, 'xgb__max_bin': 512}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-11 22:11:05,222] Trial 3 finished with value: 0.8746427785983026 and parameters: {'max_depth': 3, 'max_leaves': 234, 'min_child_weight': 3, 'gamma': 0.662522284353982, 'subsample': 0.7246844304357644, 'colsample_bytree': 0.8080272084711243, 'colsample_bylevel': 0.8186841117373118, 'colsample_bynode': 0.6739417822102108, 'learning_rate': 0.27051668818999286, 'n_estimators': 787, 'reg_alpha': 0.9394989415641891, 'reg_lambda': 0.8948273504276488, 'max_delta_step': 6, 'xgb__max_bin': 960}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-12 02:16:28,691] Trial 4 finished with value: 0.70804977020623 and parameters: {'max_depth': 3, 'max_leaves': 56, 'min_child_weight': 1, 'gamma': 0.32533033076326434, 'subsample': 0.7554709158757928, 'colsample_bytree': 0.7085396127095583, 'colsample_bylevel': 0.9314950036607718, 'colsample_bynode': 0.7427013306774357, 'learning_rate': 0.026000059117302653, 'n_estimators': 566, 'reg_alpha': 0.14092422497476265, 'reg_lambda': 0.8021969807540397, 'max_delta_step': 0, 'xgb__max_bin': 1024}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-12 02:33:49,843] Trial 5 finished with value: 0.7716297254928237 and parameters: {'max_depth': 10, 'max_leaves': 57, 'min_child_weight': 1, 'gamma': 0.8154614284548342, 'subsample': 0.8827429375390468, 'colsample_bytree': 0.8916028672163949, 'colsample_bylevel': 0.9085081386743783, 'colsample_bynode': 0.6296178606936361, 'learning_rate': 0.0338452204120114, 'n_estimators': 160, 'reg_alpha': 0.8631034258755935, 'reg_lambda': 0.6232981268275579, 'max_delta_step': 3, 'xgb__max_bin': 128}. Best is trial 0 with value: 0.9139781306277092.
# [I 2025-05-12 04:15:00,455] Trial 6 finished with value: 0.9248440833322509 and parameters: {'max_depth': 6, 'max_leaves': 88, 'min_child_weight': 8, 'gamma': 0.6375574713552131, 'subsample': 0.9548850970305306, 'colsample_bytree': 0.7888859700647797, 'colsample_bylevel': 0.6478376983753207, 'colsample_bynode': 0.885297914889198, 'learning_rate': 0.13297554090738672, 'n_estimators': 583, 'reg_alpha': 0.770967179954561, 'reg_lambda': 0.49379559636439074, 'max_delta_step': 5, 'xgb__max_bin': 448}. Best is trial 6 with value: 0.9248440833322509.
# [I 2025-05-12 05:11:29,273] Trial 7 finished with value: 0.7583188401002948 and parameters: {'max_depth': 3, 'max_leaves': 34, 'min_child_weight': 1, 'gamma': 0.6364104112637804, 'subsample': 0.7257423924305306, 'colsample_bytree': 0.8034282764658811, 'colsample_bylevel': 0.9630265895704372, 'colsample_bynode': 0.69971689165955, 'learning_rate': 0.040381768820718394, 'n_estimators': 768, 'reg_alpha': 0.22879816549162246, 'reg_lambda': 0.07697990982879299, 'max_delta_step': 3, 'xgb__max_bin': 192}. Best is trial 6 with value: 0.9248440833322509.
# [I 2025-05-12 06:48:03,289] Trial 8 finished with value: 0.9421441907537537 and parameters: {'max_depth': 12, 'max_leaves': 209, 'min_child_weight': 7, 'gamma': 0.8714605901877177, 'subsample': 0.9214688307596458, 'colsample_bytree': 0.6746280235544143, 'colsample_bylevel': 0.9570235993959911, 'colsample_bynode': 0.8157368967662603, 'learning_rate': 0.1558428978238547, 'n_estimators': 902, 'reg_alpha': 0.3180034749718639, 'reg_lambda': 0.11005192452767676, 'max_delta_step': 2, 'xgb__max_bin': 448}. Best is trial 8 with value: 0.9421441907537537.
# [I 2025-05-12 09:31:37,664] Trial 9 finished with value: 0.9567471439477021 and parameters: {'max_depth': 11, 'max_leaves': 222, 'min_child_weight': 1, 'gamma': 0.5107473025775657, 'subsample': 0.7669644012595116, 'colsample_bytree': 0.6888431241882921, 'colsample_bylevel': 0.6479461469334731, 'colsample_bynode': 0.7350460685614512, 'learning_rate': 0.24705404270823272, 'n_estimators': 357, 'reg_alpha': 0.5187906217433661, 'reg_lambda': 0.7030189588951778, 'max_delta_step': 3, 'xgb__max_bin': 1024}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-12 13:08:46,952] Trial 10 finished with value: 0.8471764128050854 and parameters: {'max_depth': 12, 'max_leaves': 181, 'min_child_weight': 10, 'gamma': 0.017961875614819767, 'subsample': 0.8560354009870226, 'colsample_bytree': 0.6154900799844731, 'colsample_bylevel': 0.7031707810405967, 'colsample_bynode': 0.7700376455370831, 'learning_rate': 0.01390703813694575, 'n_estimators': 394, 'reg_alpha': 0.5904746895937297, 'reg_lambda': 0.32122965637617135, 'max_delta_step': 10, 'xgb__max_bin': 768}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-12 16:34:10,718] Trial 11 finished with value: 0.9377649662280845 and parameters: {'max_depth': 12, 'max_leaves': 165, 'min_child_weight': 5, 'gamma': 0.9941501598986417, 'subsample': 0.9632875729376048, 'colsample_bytree': 0.6032733092915545, 'colsample_bylevel': 0.7449885280965923, 'colsample_bynode': 0.8415065442720225, 'learning_rate': 0.29660343683753626, 'n_estimators': 916, 'reg_alpha': 0.4194050635979504, 'reg_lambda': 0.03358588493447212, 'max_delta_step': 5, 'xgb__max_bin': 768}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-12 17:32:49,478] Trial 12 finished with value: 0.9565853626155201 and parameters: {'max_depth': 10, 'max_leaves': 198, 'min_child_weight': 6, 'gamma': 0.3600558713315042, 'subsample': 0.8476671509616371, 'colsample_bytree': 0.7163286452629849, 'colsample_bylevel': 0.7479778479285839, 'colsample_bynode': 0.8181425379588285, 'learning_rate': 0.1460690111815767, 'n_estimators': 338, 'reg_alpha': 0.3576425972517266, 'reg_lambda': 0.2452309371547975, 'max_delta_step': 3, 'xgb__max_bin': 384}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-12 18:22:29,926] Trial 13 finished with value: 0.9493816003305859 and parameters: {'max_depth': 10, 'max_leaves': 134, 'min_child_weight': 3, 'gamma': 0.37076687357677357, 'subsample': 0.8318264197864259, 'colsample_bytree': 0.7476939256727878, 'colsample_bylevel': 0.7219997588481966, 'colsample_bynode': 0.7406086632532847, 'learning_rate': 0.13386725661775367, 'n_estimators': 311, 'reg_alpha': 0.5507363065792278, 'reg_lambda': 0.27153057757805227, 'max_delta_step': 7, 'xgb__max_bin': 320}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-12 20:25:56,246] Trial 14 finished with value: 0.9315436667465222 and parameters: {'max_depth': 10, 'max_leaves': 202, 'min_child_weight': 6, 'gamma': 0.3724714202176811, 'subsample': 0.7977992073627854, 'colsample_bytree': 0.8628454026443384, 'colsample_bylevel': 0.6763667152567552, 'colsample_bynode': 0.8454562149406778, 'learning_rate': 0.0793423791839793, 'n_estimators': 265, 'reg_alpha': 0.34494653864854996, 'reg_lambda': 0.6266344124882548, 'max_delta_step': 4, 'xgb__max_bin': 704}. Best is trial 9 with value: 0.9567471439477021.
# [I 2025-05-13 00:33:07,338] Trial 15 finished with value: 0.9644774155969447 and parameters: {'max_depth': 9, 'max_leaves': 256, 'min_child_weight': 3, 'gamma': 0.22081432745617946, 'subsample': 0.6817427853448248, 'colsample_bytree': 0.6608758789185505, 'colsample_bylevel': 0.7714211978064195, 'colsample_bynode': 0.7846413540252581, 'learning_rate': 0.1939130448097222, 'n_estimators': 475, 'reg_alpha': 0.6129627364538431, 'reg_lambda': 0.2427378315913879, 'max_delta_step': 0, 'xgb__max_bin': 896}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-13 04:50:50,694] Trial 16 finished with value: 0.9635347677088903 and parameters: {'max_depth': 8, 'max_leaves': 254, 'min_child_weight': 3, 'gamma': 0.19406665981069837, 'subsample': 0.6756521834316895, 'colsample_bytree': 0.6463723030960604, 'colsample_bylevel': 0.780188928543867, 'colsample_bynode': 0.6023340007673605, 'learning_rate': 0.23199636025325904, 'n_estimators': 490, 'reg_alpha': 0.663909640447541, 'reg_lambda': 0.639842571981031, 'max_delta_step': 0, 'xgb__max_bin': 896}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-13 09:48:28,796] Trial 17 finished with value: 0.943076171913089 and parameters: {'max_depth': 8, 'max_leaves': 253, 'min_child_weight': 3, 'gamma': 0.15038320274499078, 'subsample': 0.6749267363543027, 'colsample_bytree': 0.6428195488709709, 'colsample_bylevel': 0.7895072053673128, 'colsample_bynode': 0.6026906532333121, 'learning_rate': 0.0743770899894238, 'n_estimators': 496, 'reg_alpha': 0.6844869645443965, 'reg_lambda': 0.33027534933459113, 'max_delta_step': 0, 'xgb__max_bin': 896}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-13 15:29:38,512] Trial 18 finished with value: 0.9611140753493753 and parameters: {'max_depth': 7, 'max_leaves': 143, 'min_child_weight': 4, 'gamma': 0.20781126705745656, 'subsample': 0.6109213047518848, 'colsample_bytree': 0.7532579305819782, 'colsample_bylevel': 0.8562120533462522, 'colsample_bynode': 0.994517152626456, 'learning_rate': 0.206537934249192, 'n_estimators': 656, 'reg_alpha': 0.993989841856686, 'reg_lambda': 0.4145917565949375, 'max_delta_step': 0, 'xgb__max_bin': 832}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-13 19:03:13,431] Trial 19 finished with value: 0.9433385109118602 and parameters: {'max_depth': 9, 'max_leaves': 99, 'min_child_weight': 2, 'gamma': 0.10032875361844684, 'subsample': 0.6840614178531207, 'colsample_bytree': 0.6347264216551218, 'colsample_bylevel': 0.7838092371816207, 'colsample_bynode': 0.6996525241997152, 'learning_rate': 0.10105811406438253, 'n_estimators': 500, 'reg_alpha': 0.6724228151424394, 'reg_lambda': 0.16233269364613911, 'max_delta_step': 1, 'xgb__max_bin': 640}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-13 22:41:10,498] Trial 20 finished with value: 0.9343073897380461 and parameters: {'max_depth': 6, 'max_leaves': 165, 'min_child_weight': 4, 'gamma': 0.25910835541036964, 'subsample': 0.712467831140401, 'colsample_bytree': 0.9772145172619293, 'colsample_bylevel': 0.8858459750613503, 'colsample_bynode': 0.6020546062414132, 'learning_rate': 0.19288100068069133, 'n_estimators': 443, 'reg_alpha': 0.8300799271190697, 'reg_lambda': 0.6138262008865331, 'max_delta_step': 8, 'xgb__max_bin': 896}. Best is trial 15 with value: 0.9644774155969447.
# [I 2025-05-14 03:41:48,295] Trial 21 finished with value: 0.9607329738703905 and parameters: {'max_depth': 7, 'max_leaves': 119, 'min_child_weight': 4, 'gamma': 0.25423671215836346, 'subsample': 0.619931471234851, 'colsample_bytree': 0.7565425960117019, 'colsample_bylevel': 0.8631302633296937, 'colsample_bynode': 0.879540518252715, 'learning_rate': 0.22076518526678018, 'n_estimators': 641, 'reg_alpha': 0.991074097187078, 'reg_lambda': 0.4097268442223098, 'max_delta_step': 0, 'xgb__max_bin': 832}. Best is trial 15 with value: 0.9644774155969447.

# %% [markdown]
# ```
# {
# 'max_depth': 9,
# 'max_leaves': 256,
# 'min_child_weight': 3,
# 'gamma': 0.22081432745617946,
# 'subsample': 0.6817427853448248,
# 'colsample_bytree': 0.6608758789185505,
# 'colsample_bylevel': 0.7714211978064195,
# 'colsample_bynode': 0.7846413540252581,
# 'learning_rate': 0.1939130448097222,
# 'n_estimators': 475,
# 'reg_alpha': 0.6129627364538431,
# 'reg_lambda': 0.2427378315913879,
# 'max_delta_step': 0, 'xgb__max_bin': 896
# }
# ```
